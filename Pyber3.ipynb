# %%
#Import libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
city = "city_data1.csv"
ride = "ride_data1.csv"

city_data = pd.read_csv(city, low_memory = False)
ride_data = pd.read_csv(ride,  low_memory = False)

city_data.head()
ride_data.head()
# Out:
#           city                 date   fare        ride_id
# 0     Sarabury  2016-01-16 13:49:27  38.35  5403689035038
# 1    South Roy  2016-01-02 18:42:34  17.49  4036272335942
# 2  Wiseborough  2016-01-21 17:35:29  44.18  3645042422587
# 3  Spencertown  2016-07-31 14:53:22   6.87  2242596575892
# 4   Nguyenbury  2016-07-09 04:42:44   6.28  1543057793673

# %%
city_ride_data = pd.merge(ride_data, city_data, how='left', on=['city', 'city'])
city_ride_data.head()
# Out:
#           city                 date   fare        ride_id  driver_count   type
# 0     Sarabury  2016-01-16 13:49:27  38.35  5403689035038            46  Urban
# 1    South Roy  2016-01-02 18:42:34  17.49  4036272335942            35  Urban
# 2  Wiseborough  2016-01-21 17:35:29  44.18  3645042422587            55  Urban
# 3  Spencertown  2016-07-31 14:53:22   6.87  2242596575892            68  Urban
# 4   Nguyenbury  2016-07-09 04:42:44   6.28  1543057793673             8  Urban

# %%
urban_cities = city_ride_data[city_ride_data["type"] == "Urban"]
urban_cities.head()
# Out:
#           city                 date   fare        ride_id  driver_count   type
# 0     Sarabury  2016-01-16 13:49:27  38.35  5403689035038            46  Urban
# 1    South Roy  2016-01-02 18:42:34  17.49  4036272335942            35  Urban
# 2  Wiseborough  2016-01-21 17:35:29  44.18  3645042422587            55  Urban
# 3  Spencertown  2016-07-31 14:53:22   6.87  2242596575892            68  Urban
# 4   Nguyenbury  2016-07-09 04:42:44   6.28  1543057793673             8  Urban

# %%
suburban_cities = city_ride_data[city_ride_data["type"] == "Suburban"]
suburban_cities.head()
# Out:
#                   city                 date   fare        ride_id  \
# 1625        Port James  2016-12-04 06:16:36  15.77  2259499336994
# 1626        Port James  2016-12-04 06:16:36  15.77  2259499336994
# 1627  New Samanthaside  2016-06-05 14:36:58  39.38  3647873452658
# 1628   Port Alexandria  2016-07-29 09:30:09  24.86  2962960319234
# 1629       Lake Brenda  2016-08-26 03:07:30  20.97  5231983896020
#
#       driver_count      type
# 1625            15  Suburban
# 1626             3  Suburban
# 1627            16  Suburban
# 1628            27  Suburban
# 1629            24  Suburban

# %%
rural_cities = city_ride_data[city_ride_data["type"] == "Rural"]
rural_cities.head()
# Out:
#               city                 date   fare        ride_id  driver_count  \
# 2282     Horneland  2016-07-19 10:07:33  12.63  8214498891817             8
# 2283     Kinghaven  2016-05-18 23:28:12  20.53  6432117120069             3
# 2284  New Johnbury  2016-04-21 08:30:25  56.60  9002881309143             6
# 2285  South Joseph  2016-02-17 01:41:29  57.52  7365786843443             3
# 2286  Kennethburgh  2016-10-19 13:13:17  24.43  2728236352387             3
#
#        type
# 2282  Rural
# 2283  Rural
# 2284  Rural
# 2285  Rural
# 2286  Rural

# %%
urban_group = urban_cities.groupby("city")
urban_group.head()

urban_average_fare = urban_group["fare"].mean()
urban_average_fare

urban_rides_count = urban_group["ride_id"].count()
urban_rides_count

urban_driver_count = urban_group["driver_count"].mean()
urban_driver_count
# Out:
# city
# Alvarezhaven         21
# Alyssaberg           67
# Antoniomouth         21
# Aprilchester         49
# Arnoldview           41
# Carrollfort          55
# Davidtown            73
# Davistown            25
# East Douglas         12
# East Erin            43
# Edwardsbury          11
# Eriktown             15
# Fosterside           69
# Jacobfort            52
# Kellershire          51
# Kelseyland           63
# Kimberlychester      13
# Lake Jeffreyland     15
# Lake Jennaton        65
# Lake Sarashire        8
# Lake Stevenbury      63
# Lisatown             47
# Lisaville            66
# Maryside             20
# Mooreview            34
# New Aaron            60
# New Andreamouth      42
# New Christine        22
# New David            31
# New Jeffrey          58
#                      ..
# Port Martinberg      44
# Port Samantha        55
# Prattfurt            43
# Rodriguezburgh       52
# Russellport           9
# Sandymouth           11
# Sarabury             46
# ...

# %%
suburban_group = suburban_cities.groupby("city")
suburban_group.head()

suburban_average_fare = suburban_group["fare"].mean()
suburban_average_fare

suburban_rides_count = suburban_group["ride_id"].count()
suburban_rides_count

suburban_driver_count = suburban_group["driver_count"].mean()
suburban_driver_count
# Out:
# city
# Anitamouth              16
# Campbellport            26
# Carrollbury              4
# Clarkstad               21
# Conwaymouth             18
# East Cherylfurt          9
# East Jenniferchester    22
# Floresberg               7
# Jasonfort               25
# Jeffreyton               8
# Johnland                13
# Kyleton                 12
# Lake Brenda             24
# Martinmouth              5
# New Brandonborough       9
# New Cindyborough        20
# New Jessicamouth        22
# New Lynn                20
# New Michelleberg         9
# New Samanthaside        16
# North Tara              14
# North Tracyfort         18
# Paulfort                13
# Port Alexandria         27
# Port Guytown            26
# Port James               9
# Port Jose               11
# Port Michelleview       16
# Rodriguezview           10
# Sarahview               18
# South Gracechester      19
# South Jennifer           6
# South Shannonborough     9
# Thomastown               1
# ...

# %%
rural_group = rural_cities.groupby("city")
rural_group.head()

rural_average_fare = rural_group["fare"].mean()
rural_average_fare

rural_rides_count = rural_group["ride_id"].count()
rural_rides_count

rural_driver_count = rural_group["driver_count"].mean()
rural_driver_count
# Out:
# city
# East Leslie              9
# East Stephen             6
# East Troybury            3
# Erikport                 3
# Hernandezshire          10
# Horneland                8
# Jacksonfort              6
# Kennethburgh             3
# Kinghaven                3
# Manuelchester            7
# Matthewside              4
# New Johnbury             6
# North Whitney           10
# Shelbyhaven              9
# South Elizabethmouth     3
# South Joseph             3
# Stevensport              6
# West Kevintown           5
# Name: driver_count, dtype: int64

# %%
plt.scatter(x=urban_rides_count,
            y=urban_average_fare,
            s=urban_driver_count,
            marker='o', facecolors='gold', edgecolors="black",
            alpha=0.9, label="urban")

plt.scatter(x=suburban_rides_count,
            y=suburban_average_fare,
            s=suburban_driver_count,
            marker='o', facecolors='lightblue', edgecolors="black",
            alpha=0.9, label="suburban")

plt.scatter(x=rural_rides_count,
            y=rural_average_fare,
            s=rural_driver_count,
            marker='o', facecolors='lightcoral', edgecolors="black",
            alpha=0.9,label="rural")


# Create a legend
lgnd = plt.legend(fontsize="small", mode="Expanded",
                 numpoints=1, scatterpoints=1,
                 loc="best", title="City Types",
                 labelspacing=0.5)
lgnd.legendHandles[2]._sizes = [30]
lgnd.legendHandles[2]._sizes = [30]
lgnd.legendHandles[2]._sizes = [30]

plt.title("Pyber Ride Sharing Data (2016)")
plt.xlabel("Total Number of Rides per city")
plt.ylabel("Average Fare ($) per city")

plt.show()

# %%
#
#Total Fares Per City Type
#
tot_fares_by_city_type_group = city_ride_data.groupby("type")
percent_total_fares_by_city_type = (tot_fares_by_city_type_group["fare"].sum() / city_ride_data["fare"].sum()) * 100
percent_total_fares_by_city_type

tot_fares_by_city_type_summary = pd.DataFrame ({"Percentage" : percent_total_fares_by_city_type })
tot_fares_by_city_type_summary = tot_fares_by_city_type_summary.reset_index()
tot_fares_by_city_type_summary.head()

colors = ["gold", "lightblue", "lightcoral"]
explode = (0, 0, 0)
plt.pie(tot_fares_by_city_type_summary['Percentage'], explode=explode, labels=tot_fares_by_city_type_summary['type'], colors=colors,
       autopct="%1.1f%%", shadow=True, startangle=140)
#Tells matplotlib that we want a pie chart with equal axes
plt.axis("equal")

plt.title("% of Total Fares By City Type")

plt.show()

# %%
#
#Total Rides Per City Type
#
tot_rides_by_city_type_group = city_ride_data.groupby("type")
percent_total_rides_by_city_type = (tot_rides_by_city_type_group["ride_id"].count() / city_ride_data["ride_id"].count()) * 100
percent_total_rides_by_city_type

#Question - do we really need to convert to a dataframe?
tot_rides_by_city_type_summary = pd.DataFrame ({"Percentage" : percent_total_rides_by_city_type })
tot_rides_by_city_type_summary = tot_rides_by_city_type_summary.reset_index()
tot_rides_by_city_type_summary.head()

colors = ["gold", "lightblue", "lightcoral"]
explode = (0, 0, 0)
plt.pie(tot_rides_by_city_type_summary['Percentage'], explode=explode, labels=tot_rides_by_city_type_summary['type'], colors=colors,
       autopct="%1.1f%%", shadow=True, startangle=140)
#Tells matplotlib that we want a pie chart with equal axes
plt.axis("equal")

plt.title("% of Total Rides By City Type")

plt.show()

# %%
#
#Total Drivers Per City Type
#
tot_drivers_by_city_type_group = city_ride_data.groupby("type")
percent_drivers_by_city_type = (tot_drivers_by_city_type_group["driver_count"].sum() / city_ride_data["driver_count"].sum()) * 100
percent_drivers_by_city_type

tot_drivers_by_city_type_summary = pd.DataFrame ({"Percentage" : percent_drivers_by_city_type })
tot_drivers_by_city_type_summary = tot_drivers_by_city_type_summary.reset_index()
tot_drivers_by_city_type_summary.head()

colors = ["gold", "lightblue", "lightcoral"]
explode = (0, 0, 0)
plt.pie(tot_drivers_by_city_type_summary['Percentage'], explode=explode, labels=tot_drivers_by_city_type_summary['type'], colors=colors,
       autopct="%1.1f%%", shadow=True, startangle=140)
#Tells matplotlib that we want a pie chart with equal axes
plt.axis("equal")

plt.title("% of Total Drivers By City Type")

plt.show()
