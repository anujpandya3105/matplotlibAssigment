# %%
#Import libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Take in city and ride data and read it into pandas
city = "city_data.csv"
ride = "ride_data.csv"

ride_df = pd.read_csv(ride,  low_memory = False)
city_df = pd.read_csv(city, low_memory = False)

city_df.head()
# Out:
#              city  driver_count   type
# 0      Kelseyland            63  Urban
# 1      Nguyenbury             8  Urban
# 2    East Douglas            12  Urban
# 3   West Dawnfurt            34  Urban
# 4  Rodriguezburgh            52  Urban

# %%
combined_city_ride_dirty_df = pd.merge(ride_df, city_df, how='outer', on='city')
combined_city_ride_dirty_df
combined_city_ride_df = combined_city_ride_dirty_df[['city', 'date', 'fare', 'ride_id', 'driver_count', 'type']]
combined_city_ride_df_clean = combined_city_ride_df.dropna(how='any')
combined_city_ride_df_clean.head(5)
# Out:
#        city             date   fare       ride_id  driver_count   type
# 0  Sarabury  1/16/2016 13:49  38.35  5.403690e+12          46.0  Urban
# 1  Sarabury   7/23/2016 7:42  21.76  7.546680e+12          46.0  Urban
# 2  Sarabury    4/2/2016 4:32  38.03  4.932500e+12          46.0  Urban
# 3  Sarabury   6/23/2016 5:03  26.82  6.711040e+12          46.0  Urban
# 4  Sarabury  9/30/2016 12:48  30.30  6.388740e+12          46.0  Urban

# %%
group_city = combined_city_ride_df_clean.groupby('city')
group_city.head(5)
# Out:
#                       city              date   fare       ride_id  \
# 0                 Sarabury   1/16/2016 13:49  38.35  5.403690e+12
# 1                 Sarabury    7/23/2016 7:42  21.76  7.546680e+12
# 2                 Sarabury     4/2/2016 4:32  38.03  4.932500e+12
# 3                 Sarabury    6/23/2016 5:03  26.82  6.711040e+12
# 4                 Sarabury   9/30/2016 12:48  30.30  6.388740e+12
# 27               South Roy    1/2/2016 18:42  17.49  4.036270e+12
# 28               South Roy    12/3/2016 8:39  32.88  7.098920e+12
# 29               South Roy   11/20/2016 2:09   6.81  6.512610e+12
# 30               South Roy    4/14/2016 3:24   9.77  6.642120e+11
# 31               South Roy     7/6/2016 7:37  21.04  9.000260e+11
# 49             Wiseborough   1/21/2016 17:35  44.18  3.645040e+12
# 50             Wiseborough   9/12/2016 18:43  26.83  9.304730e+12
# 51             Wiseborough    10/1/2016 9:57  37.84  1.617740e+12
# 52             Wiseborough    9/12/2016 0:38  20.62  8.634930e+12
# 53             Wiseborough  10/29/2016 19:14  13.85  8.841220e+12
# 68             Spencertown   7/31/2016 14:53   6.87  2.242600e+12
# 69             Spencertown    7/12/2016 2:52  31.39  7.547490e+11
# 70             Spencertown    6/13/2016 3:01  25.91  7.414420e+12
# 71             Spencertown   1/16/2016 18:28  35.59  7.002930e+12
# 72             Spencertown   8/11/2016 12:33  12.76  4.525750e+11
# 94              Nguyenbury     7/9/2016 4:42   6.28  1.543060e+12
# 95              Nguyenbury   11/8/2016 19:22  19.49  1.702800e+12
# 96              Nguyenbury   3/19/2016 13:08  35.07  9.198400e+12
# 97              Nguyenbury   5/12/2016 15:57  41.63  2.246840e+11
# 53            55.0  Urban
# 68            68.0  Urban
# 69            68.0  Urban
# 70            68.0  Urban
# 71            68.0  Urban
# 72            68.0  Urban
# 94             8.0  Urban
# 95             8.0  Urban
# 96             8.0  Urban
# 97             8.0  Urban
# 98             8.0  Urban
# 120           58.0  Urban
# 121           58.0  Urban
# 122           58.0  Urban
# 123           58.0  Urban
# 124           58.0  Urban
# ...            ...    ...
# 2364           6.0  Rural
# 2365           6.0  Rural
# 2366           6.0  Rural
# 2367           6.0  Rural
# 2368           6.0  Rural
# 2370           9.0  Rural
# 2371           9.0  Rural
# 2372           9.0  Rural
# 2373           9.0  Rural
# 2374           9.0  Rural
# 2381          10.0  Rural
# 2382          10.0  Rural
# 2383          10.0  Rural
# 2384          10.0  Rural
# 2385          10.0  Rural
# 2391           7.0  Rural
# 2392           9.0  Rural
# 2393           9.0  Rural
# 2394           9.0  Rural
# 2395           9.0  Rural
# 2396           9.0  Rural
# 2398           3.0  Rural
# 2399           3.0  Rural
# 2400           3.0  Rural
# 2401           3.0  Rural
# 2402           3.0  Rural
# 2403           4.0  Rural
# 2404           4.0  Rural
# 2405           4.0  Rural
# 2406           4.0  Rural
#
# [618 rows x 6 columns]

# %%
av_per_city = group_city['fare'].mean()
av_per_city
# Out:
# city
# Alvarezhaven            23.928710
# Alyssaberg              20.609615
# Anitamouth              37.315556
# Antoniomouth            23.625000
# Aprilchester            21.981579
# Arnoldview              25.106452
# Campbellport            33.711333
# Carrollbury             36.606000
# Carrollfort             25.395517
# Clarkstad               31.051667
# Conwaymouth             34.591818
# Davidtown               22.978095
# Davistown               21.497200
# East Cherylfurt         31.416154
# East Douglas            26.169091
# East Erin               24.478214
# East Jenniferchester    32.599474
# East Leslie             33.660909
# East Stephen            39.053000
# East Troybury           33.244286
# Edwardsbury             26.876667
# Erikport                30.043750
# Eriktown                25.478947
# Floresberg              32.310000
# Fosterside              23.034583
# Hernandezshire          32.002222
# Horneland               21.482500
# Jacksonfort             32.006667
# Jacobfort               24.779355
# Jasonfort               27.831667
#                           ...
# South Roy               26.031364
# South Shannonborough    26.516667
# Spencertown             23.681154
# Stevensport             31.948000
# Stewartview             21.614000
# Swansonbury             27.464706
# Thomastown              30.308333
# Tiffanyton              28.510000
# Torresshire             24.207308
# Travisville             27.220870
# Vickimouth              21.474667
# Webstertown             29.721250
# West Alexis             19.523000
# West Brandy             24.157667
# West Brittanyton        25.436250
# West Dawnfurt           22.330345
# West Evan               27.013333
# West Jefferyfurt        21.072857
# West Kevintown          21.528571
# West Oscar              24.280000
# West Pamelaborough      33.799286
# West Paulport           33.278235
# West Peter              24.875484
# West Sydneyhaven        22.368333
# West Tony               29.609474
# Williamchester          34.278182
# Williamshire            26.990323
# Wiseborough             22.676842
# Yolandafurt             27.205500
# Zimmermanmouth          28.301667
# Name: fare, Length: 125, dtype: float64

# %%
tot_rides_per_city = group_city['ride_id'].count()
tot_rides_per_city
# Out:
# city
# Alvarezhaven            31
# Alyssaberg              26
# Anitamouth               9
# Antoniomouth            22
# Aprilchester            19
# Arnoldview              31
# Campbellport            15
# Carrollbury             10
# Carrollfort             29
# Clarkstad               12
# Conwaymouth             11
# Davidtown               21
# Davistown               25
# East Cherylfurt         13
# East Douglas            22
# East Erin               28
# East Jenniferchester    19
# East Leslie             11
# East Stephen            10
# East Troybury            7
# Edwardsbury             27
# Erikport                 8
# Eriktown                19
# Floresberg              10
# Fosterside              24
# Hernandezshire           9
# Horneland                4
# Jacksonfort              6
# Jacobfort               31
# Jasonfort               12
#                         ..
# South Roy               22
# South Shannonborough    15
# Spencertown             26
# Stevensport              5
# Stewartview             30
# Swansonbury             34
# Thomastown              24
# Tiffanyton              13
# Torresshire             26
# Travisville             23
# Vickimouth              15
# Webstertown             16
# West Alexis             20
# West Brandy             30
# West Brittanyton        24
# West Dawnfurt           29
# West Evan               12
# West Jefferyfurt        21
# West Kevintown           7
# West Oscar              29
# West Pamelaborough      14
# West Paulport           17
# West Peter              31
# West Sydneyhaven        18
# West Tony               19
# Williamchester          11
# Williamshire            31
# Wiseborough             19
# Yolandafurt             20
# Zimmermanmouth          24
# Name: ride_id, Length: 125, dtype: int64

# %%
rides_df = pd.DataFrame ({"rider_count" : tot_rides_per_city,
                         "average_fare" : av_per_city})

rides_df.head()
# Out:
#               average_fare  rider_count
# city
# Alvarezhaven     23.928710           31
# Alyssaberg       20.609615           26
# Anitamouth       37.315556            9
# Antoniomouth     23.625000           22
# Aprilchester     21.981579           19

# %%
#new_city_df = city_df.set_index('city')
#new_city_df.head(2)
new_rides_df = rides_df.reset_index()
new_rides_df.head()
city_df.head()
# Out:
#              city  driver_count   type
# 0      Kelseyland            63  Urban
# 1      Nguyenbury             8  Urban
# 2    East Douglas            12  Urban
# 3   West Dawnfurt            34  Urban
# 4  Rodriguezburgh            52  Urban

# %%
#### WHY DO THESE NOT MERGE !!!!!!!!!!!!!!!!!! #####
###To merge 2 data frames do not merge by index, i had to reset the index of the rides_df
### so i reset the index on the rides data frame and then joined city and rides data frames###
###Now I have one consolidated DF, with the city as key.
rides_and_city_merge_df = pd.merge(new_rides_df, city_df, on='city')
rides_and_city_merge_df.head()
# Out:
#            city  average_fare  rider_count  driver_count      type
# 0  Alvarezhaven     23.928710           31            21     Urban
# 1    Alyssaberg     20.609615           26            67     Urban
# 2    Anitamouth     37.315556            9            16  Suburban
# 3  Antoniomouth     23.625000           22            21     Urban
# 4  Aprilchester     21.981579           19            49     Urban

# %%
#plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black",
#            s=x_axis, alpha=0.75)
#rides_and_city_merge_df.plot(kind="scatter", x="rider_count", y="average_fare", s="driver_count", c="type", alpha=0.5)
#rides_and_city_merge_df.plot(kind="scatter", x="rider_count", y="average_fare",  alpha=0.5)
plt.scatter(x=rides_and_city_merge_df['rider_count'],
            y=rides_and_city_merge_df['average_fare'],
            s=rides_and_city_merge_df['driver_count'],
            marker='o', facecolors='red', edgecolors="black",
            alpha=0.5)

plt.title("Pyber Ride Sharing Data (2016)")
plt.xlabel("Total Number of Rides per city")
plt.ylabel("Average Fare ($) per city")
plt.show()

# %%
#Total Fares per city type
   
fares_per_city_type_df = rides_and_city_merge_df[ ['average_fare' , 'type'] ]
fares_per_city_type_df.head()
group_fares_by_city_type = fares_per_city_type_df.groupby('type')
group_fares_by_city_type.head(150)

s = group_fares_by_city_type['average_fare'].sum()
c = group_fares_by_city_type['type'].count()

group_fares_by_city_type_summary = pd.DataFrame ({"Percentage" : (s/c) })
new_group_fares_by_city_type_summary= group_fares_by_city_type_summary.reset_index()
new_group_fares_by_city_type_summary.head()
# Out:
#        type  Percentage
# 0     Rural   34.207143
# 1  Suburban   30.962713
# 2     Urban   24.603991

# %%
colors = ["yellowgreen", "red", "lightcoral"]
explode = (0.1, 0, 0)
plt.pie(new_group_fares_by_city_type_summary['Percentage'], explode=explode, labels=new_group_fares_by_city_type_summary['type'], colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Tells matplotlib that we want a pie chart with equal axes
plt.axis("equal")

plt.show()

# %%
#Total Rides per city type
   
rides_per_city_type_df = rides_and_city_merge_df[ ['rider_count' , 'type'] ]
rides_per_city_type_df.head()

group_rides_by_city_type = rides_per_city_type_df.groupby('type')
group_rides_by_city_type.head(5)

s = group_rides_by_city_type['rider_count'].sum()
c = group_rides_by_city_type['type'].count()

group_rides_by_city_type_summary = pd.DataFrame ({"Percentage" : (s/c) })
new_group_rides_by_city_type_summary= group_rides_by_city_type_summary.reset_index()
new_group_rides_by_city_type_summary.head()
# Out:
#        type  Percentage
# 0     Rural    6.944444
# 1  Suburban   17.166667
# 2     Urban   24.621212

# %%
colors = ["yellowgreen", "red", "lightcoral"]
explode = (0.1, 0, 0)
plt.pie(new_group_rides_by_city_type_summary['Percentage'], explode=explode, labels=new_group_rides_by_city_type_summary['type'], colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Tells matplotlib that we want a pie chart with equal axes
plt.axis("equal")

plt.show()

# %%
#
#Total Drivers per city type
#

drivers_per_city_type_df = rides_and_city_merge_df[ ['driver_count' , 'type'] ]
drivers_per_city_type_df.head()

group_drivers_by_city_type = drivers_per_city_type_df.groupby('type')
group_drivers_by_city_type.head(2)

s = group_drivers_by_city_type['driver_count'].sum()
c = group_drivers_by_city_type['type'].count()

group_drivers_by_city_type_summary = pd.DataFrame ({"Percentage" : (s/c) })
new_group_drivers_by_city_type_summary= group_drivers_by_city_type_summary.reset_index()
new_group_drivers_by_city_type_summary.head()


colors = ["yellowgreen", "red", "lightcoral"]
explode = (0.1, 0, 0)
plt.pie(new_group_drivers_by_city_type_summary['Percentage'], explode=explode, labels=new_group_drivers_by_city_type_summary['type'], colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Tells matplotlib that we want a pie chart with equal axes
plt.axis("equal")

plt.show()
